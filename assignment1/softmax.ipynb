# %% [markdown]
# # Softmax exercise
#
# *Complete and hand in this completed worksheet (including its outputs and any supporting code outside of the worksheet) with your assignment submission. For more details see the [assignments page](http://vision.stanford.edu/teaching/cs231n/assignments.html) on the course website.*
#
# This exercise is analogous to the SVM exercise. You will:
#
# - implement a fully-vectorized **loss function** for the Softmax classifier
# - implement the fully-vectorized expression for its **analytic gradient**
# - **check your implementation** with numerical gradient
# - use a validation set to **tune the learning rate and regularization** strength
# - **optimize** the loss function with **SGD**
# - **visualize** the final learned weights

# %%
import random
import numpy as np
from cs231n.data_utils import load_CIFAR10
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams['figure.figsize'] = (10.0, 8.0) # set default size of plots
plt.rcParams['image.interpolation'] = 'nearest'
plt.rcParams['image.cmap'] = 'gray'

# for auto-reloading extenrnal modules
# see http://stackoverflow.com/questions/1907993/autoreload-of-modules-in-ipython
# %load_ext autoreload
# %autoreload 2

# %%
def get_CIFAR10_data(num_training=49000, num_validation=1000, num_test=1000, num_dev=500):
  """
  Load the CIFAR-10 dataset from disk and perform preprocessing to prepare
  it for the linear classifier. These are the same steps as we used for the
  SVM, but condensed to a single function.  
  """
  # Load the raw CIFAR-10 data
  cifar10_dir = 'cs231n/datasets/cifar-10-batches-py'
  X_train, y_train, X_test, y_test = load_CIFAR10(cifar10_dir)
  
  # subsample the data
  mask = range(num_training, num_training + num_validation)
  X_val = X_train[mask]
  y_val = y_train[mask]
  mask = range(num_training)
  X_train = X_train[mask]
  y_train = y_train[mask]
  mask = range(num_test)
  X_test = X_test[mask]
  y_test = y_test[mask]
  mask = np.random.choice(num_training, num_dev, replace=False)
  X_dev = X_train[mask]
  y_dev = y_train[mask]
  
  # Preprocessing: reshape the image data into rows
  X_train = np.reshape(X_train, (X_train.shape[0], -1))
  X_val = np.reshape(X_val, (X_val.shape[0], -1))
  X_test = np.reshape(X_test, (X_test.shape[0], -1))
  X_dev = np.reshape(X_dev, (X_dev.shape[0], -1))
  
  # Normalize the data: subtract the mean image
  mean_image = np.mean(X_train, axis = 0)
  X_train -= mean_image
  X_val -= mean_image
  X_test -= mean_image
  X_dev -= mean_image
  
  # add bias dimension and transform into columns
  X_train = np.hstack([X_train, np.ones((X_train.shape[0], 1))])
  X_val = np.hstack([X_val, np.ones((X_val.shape[0], 1))])
  X_test = np.hstack([X_test, np.ones((X_test.shape[0], 1))])
  X_dev = np.hstack([X_dev, np.ones((X_dev.shape[0], 1))])
  
  return X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev


# Invoke the above function to get our data.
X_train, y_train, X_val, y_val, X_test, y_test, X_dev, y_dev = get_CIFAR10_data()
print 'Train data shape: ', X_train.shape
print 'Train labels shape: ', y_train.shape
print 'Validation data shape: ', X_val.shape
print 'Validation labels shape: ', y_val.shape
print 'Test data shape: ', X_test.shape
print 'Test labels shape: ', y_test.shape
print 'dev data shape: ', X_dev.shape
print 'dev labels shape: ', y_dev.shape
# Out:
# Train data shape:  (49000, 3073)
# Train labels shape:  (49000,)
# Validation data shape:  (1000, 3073)
# Validation labels shape:  (1000,)
# Test data shape:  (1000, 3073)
# Test labels shape:  (1000,)
# dev data shape:  (500, 3073)
# dev labels shape:  (500,)

# %% [markdown]
# ## Softmax Classifier
#
# Your code for this section will all be written inside **cs231n/classifiers/softmax.py**.

# %%
# First implement the naive softmax loss function with nested loops.
# Open the file cs231n/classifiers/softmax.py and implement the
# softmax_loss_naive function.

from cs231n.classifiers.softmax import softmax_loss_naive
import time

# Generate a random softmax weight matrix and use it to compute the loss.
W = np.random.randn(3073, 10) * 0.0001
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As a rough sanity check, our loss should be something close to -log(0.1).
print 'loss: %f' % loss
print 'sanity check: %f' % (-np.log(0.1))
# Out:
# loss: 2.387853
# sanity check: 2.302585

# %% [markdown]
# ## Inline Question 1:
# Why do we expect our loss to be close to -log(0.1)? Explain briefly.**
#
# **Your answer:** *Fill this in*
# We have 10 classes and random W so the entropy loss is supposed to be 0.1

# %%
# Complete the implementation of softmax_loss_naive and implement a (naive)
# version of the gradient that uses nested loops.
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 0.0)

# As we did for the SVM, use numeric gradient checking as a debugging tool.
# The numeric gradient should be close to the analytic gradient.
from cs231n.gradient_check import grad_check_sparse
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 0.0)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)

# similar to SVM case, do another gradient check with regularization
loss, grad = softmax_loss_naive(W, X_dev, y_dev, 1e2)
f = lambda w: softmax_loss_naive(w, X_dev, y_dev, 1e2)[0]
grad_numerical = grad_check_sparse(f, W, grad, 10)
# Out:
# numerical: 1.326488 analytic: 1.326488, relative error: 1.529708e-08
# numerical: -2.167883 analytic: -2.167883, relative error: 1.640481e-08
# numerical: 0.959569 analytic: 0.959569, relative error: 5.056386e-08
# numerical: 1.144027 analytic: 1.144027, relative error: 5.319129e-08
# numerical: -2.460882 analytic: -2.460882, relative error: 1.170984e-08
# numerical: -2.022616 analytic: -2.022616, relative error: 8.383789e-09
# numerical: 0.991447 analytic: 0.991447, relative error: 2.730288e-08
# numerical: 1.149254 analytic: 1.149254, relative error: 2.611883e-08
# numerical: -1.502364 analytic: -1.502364, relative error: 1.541671e-09
# numerical: -0.230659 analytic: -0.230659, relative error: 8.035972e-08
# numerical: 1.441188 analytic: 1.441188, relative error: 5.922963e-08
# numerical: -5.716468 analytic: -5.716468, relative error: 1.303423e-09
# numerical: -0.728053 analytic: -0.728053, relative error: 4.204914e-08
# numerical: 2.617064 analytic: 2.617064, relative error: 6.458494e-09
# numerical: -0.409492 analytic: -0.409493, relative error: 1.530712e-07
# numerical: 1.747818 analytic: 1.747818, relative error: 1.183729e-08
# numerical: -1.288141 analytic: -1.288141, relative error: 1.057500e-08
# numerical: 1.731461 analytic: 1.731461, relative error: 6.832535e-08
# numerical: 1.685804 analytic: 1.685804, relative error: 5.561052e-08
# numerical: -3.482619 analytic: -3.482619, relative error: 1.391238e-09

# %%
# Now that we have a naive implementation of the softmax loss function and its gradient,
# implement a vectorized version in softmax_loss_vectorized.
# The two versions should compute the same results, but the vectorized version should be
# much faster.
tic = time.time()
loss_naive, grad_naive = softmax_loss_naive(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'naive loss: %e computed in %fs' % (loss_naive, toc - tic)

from cs231n.classifiers.softmax import softmax_loss_vectorized
tic = time.time()
loss_vectorized, grad_vectorized = softmax_loss_vectorized(W, X_dev, y_dev, 0.00001)
toc = time.time()
print 'vectorized loss: %e computed in %fs' % (loss_vectorized, toc - tic)

# As we did for the SVM, we use the Frobenius norm to compare the two versions
# of the gradient.
grad_difference = np.linalg.norm(grad_naive - grad_vectorized, ord='fro')
print 'Loss difference: %f' % np.abs(loss_naive - loss_vectorized)
print 'Gradient difference: %f' % grad_difference
# Out:
# naive loss: 2.387853e+00 computed in 0.062890s
# vectorized loss: 2.387853e+00 computed in 0.006765s
# Loss difference: 0.000000
# Gradient difference: 0.000000

# %%
# Use the validation set to tune hyperparameters (regularization strength and
# learning rate). You should experiment with different ranges for the learning
# rates and regularization strengths; if you are careful you should be able to
# get a classification accuracy of over 0.35 on the validation set.
from cs231n.classifiers import Softmax
results = {}
best_val = -1
best_softmax = None
#learning_rates = [1e-7, 5e-7]
#regularization_strengths = [5e4, 1e8]
#learning_rates = [1e-7,2e-7,3e-7,4e-7, 5e-7]
#regularization_strengths = [5e4,1e5,5e6,1e7,5e7,1e8]

#learning_rates = [i * 1e-8 for i in [1,50,100] ]
#regulation_range = np.arange(1, 11)
#regularization_strengths =[j * 1e4 for j in [1,50,100] ]

################################################################################
# TODO:                                                                        #
# Use the validation set to set the learning rate and regularization strength. #
# This should be identical to the validation that you did for the SVM; save    #
# the best trained softmax classifer in best_softmax.                          #
################################################################################
iters_num = 1500
val_acc_array=[]
softmax_obj_array=[]

MAX_COUNT = 30

for count in xrange(MAX_COUNT):
#for lrs  in learning_rates:
  #for regs in regularization_strengths:
    
    regs = 10**np.random.uniform(3,6)
    lrs = 10**np.random.uniform(-8,-6)
    
    softmax = Softmax()
    softmax_obj_array.append(softmax)
    loss_hist = softmax.train(X_train, y_train, learning_rate=lrs, reg=regs ,
                      num_iters=iters_num , verbose=False)

    print(count+1)
    print('lr %e reg %e'%(lrs , regs) )
    y_train_pred = softmax.predict(X_train)
    ta = np.mean(y_train == y_train_pred)
    print 'training accuracy: %f' % (ta, ) 
    y_val_pred = softmax.predict(X_val)
    va = np.mean(y_val == y_val_pred)
    print 'validation accuracy: %f' % (va, ) 

    results[(lrs,regs)] = (ta, va)
    val_acc_array.append(va)

best_val = max(val_acc_array)  
best_softmax  = softmax_obj_array.pop(val_acc_array.index(max(val_acc_array)))
################################################################################
#                              END OF YOUR CODE                                #
################################################################################
    
# Print out results.
for lr, reg in sorted(results):
    train_accuracy, val_accuracy = results[(lr, reg)]
    print 'lr %e reg %e train accuracy: %f val accuracy: %f' % (
                lr, reg, train_accuracy, val_accuracy)
    
print 'best validation accuracy achieved during cross-validation: %f' % best_val
# Out:
# 1
# lr 7.240355e-07 reg 9.435258e+04
# training accuracy: 0.296980
# validation accuracy: 0.303000
# 2
# lr 1.933890e-08 reg 1.839572e+05
# training accuracy: 0.289755
# validation accuracy: 0.301000
# 3
# lr 4.297505e-07 reg 1.030681e+05
# training accuracy: 0.309265
# validation accuracy: 0.309000
# 4
# lr 1.137546e-08 reg 4.190642e+03
# training accuracy: 0.154449
# validation accuracy: 0.150000
# 5
# lr 7.375310e-08 reg 1.451473e+03
# training accuracy: 0.247776
# validation accuracy: 0.241000
# 6
# lr 5.413144e-07 reg 8.662402e+04
# training accuracy: 0.309592
# validation accuracy: 0.330000
# 7
# lr 3.350478e-08 reg 4.901332e+05
# training accuracy: 0.272980
# validation accuracy: 0.283000
# 8
# lr 2.113268e-07 reg 4.599536e+03
# training accuracy: 0.360592
# validation accuracy: 0.369000
# 9
# lr 2.290433e-08 reg 1.002829e+04
# training accuracy: 0.195571
# validation accuracy: 0.198000
# 10
# lr 1.553247e-07 reg 1.864782e+05
# training accuracy: 0.286571
# validation accuracy: 0.304000
# 11
# lr 4.849789e-07 reg 1.639309e+04
# training accuracy: 0.361061
# validation accuracy: 0.366000
# 12
# lr 1.998425e-07 reg 2.702649e+03
# training accuracy: 0.329429
# validation accuracy: 0.335000
# 13
# lr 1.384479e-07 reg 8.298249e+04
# training accuracy: 0.307224
# validation accuracy: 0.317000
# 14
# lr 1.796136e-07 reg 2.294377e+04
# training accuracy: 0.354878
# validation accuracy: 0.372000
# 15
# lr 5.988164e-08 reg 6.024311e+03
# training accuracy: 0.253571
# validation accuracy: 0.275000
# 16
# lr 4.861788e-07 reg 1.546325e+04
# training accuracy: 0.360122
# validation accuracy: 0.369000
# 17
# lr 1.405640e-08 reg 5.622038e+05
# training accuracy: 0.265082
# validation accuracy: 0.273000
# 18
# lr 1.799181e-08 reg 5.751732e+04
# training accuracy: 0.222184
# validation accuracy: 0.211000
# 19
# lr 7.670295e-08 reg 1.346147e+04
# training accuracy: 0.322224
# validation accuracy: 0.340000
# 20
# lr 5.284209e-07 reg 2.734971e+05
# training accuracy: 0.260327
# validation accuracy: 0.269000
# 21
# lr 3.833581e-08 reg 1.531213e+05
# training accuracy: 0.290898
# validation accuracy: 0.311000
# 22
# lr 1.227238e-07 reg 2.727256e+03
# training accuracy: 0.285490
# validation accuracy: 0.279000
# 23
# lr 3.607839e-08 reg 1.564537e+04
# training accuracy: 0.241735
# validation accuracy: 0.251000
# 24
# lr 3.066234e-08 reg 2.200401e+03
# training accuracy: 0.210184
# validation accuracy: 0.219000
# 25
# lr 1.463770e-07 reg 5.319532e+04
# training accuracy: 0.330551
# validation accuracy: 0.343000
# 26
# lr 1.366299e-08 reg 8.916046e+04
# training accuracy: 0.231041
# validation accuracy: 0.207000
# 27
# lr 1.132355e-07 reg 1.035240e+04
# training accuracy: 0.349653
# validation accuracy: 0.361000
# 28
# lr 2.354121e-08 reg 1.902111e+03
# training accuracy: 0.196245
# validation accuracy: 0.205000
# 29
# lr 2.458138e-07 reg 1.918540e+05
# training accuracy: 0.284673
# validation accuracy: 0.296000
# 30
# lr 2.219544e-08 reg 1.664460e+05
# training accuracy: 0.293857
# validation accuracy: 0.311000
# lr 1.137546e-08 reg 4.190642e+03 train accuracy: 0.154449 val accuracy: 0.150000
# lr 1.366299e-08 reg 8.916046e+04 train accuracy: 0.231041 val accuracy: 0.207000
# lr 1.405640e-08 reg 5.622038e+05 train accuracy: 0.265082 val accuracy: 0.273000
# lr 1.799181e-08 reg 5.751732e+04 train accuracy: 0.222184 val accuracy: 0.211000
# lr 1.933890e-08 reg 1.839572e+05 train accuracy: 0.289755 val accuracy: 0.301000
# lr 2.219544e-08 reg 1.664460e+05 train accuracy: 0.293857 val accuracy: 0.311000
# lr 2.290433e-08 reg 1.002829e+04 train accuracy: 0.195571 val accuracy: 0.198000
# lr 2.354121e-08 reg 1.902111e+03 train accuracy: 0.196245 val accuracy: 0.205000
# lr 3.066234e-08 reg 2.200401e+03 train accuracy: 0.210184 val accuracy: 0.219000
# lr 3.350478e-08 reg 4.901332e+05 train accuracy: 0.272980 val accuracy: 0.283000
# lr 3.607839e-08 reg 1.564537e+04 train accuracy: 0.241735 val accuracy: 0.251000
# lr 3.833581e-08 reg 1.531213e+05 train accuracy: 0.290898 val accuracy: 0.311000
# lr 5.988164e-08 reg 6.024311e+03 train accuracy: 0.253571 val accuracy: 0.275000
# lr 7.375310e-08 reg 1.451473e+03 train accuracy: 0.247776 val accuracy: 0.241000
# lr 7.670295e-08 reg 1.346147e+04 train accuracy: 0.322224 val accuracy: 0.340000
# lr 1.132355e-07 reg 1.035240e+04 train accuracy: 0.349653 val accuracy: 0.361000
# lr 1.227238e-07 reg 2.727256e+03 train accuracy: 0.285490 val accuracy: 0.279000
# lr 1.384479e-07 reg 8.298249e+04 train accuracy: 0.307224 val accuracy: 0.317000
# lr 1.463770e-07 reg 5.319532e+04 train accuracy: 0.330551 val accuracy: 0.343000
# lr 1.553247e-07 reg 1.864782e+05 train accuracy: 0.286571 val accuracy: 0.304000
# lr 1.796136e-07 reg 2.294377e+04 train accuracy: 0.354878 val accuracy: 0.372000
# lr 1.998425e-07 reg 2.702649e+03 train accuracy: 0.329429 val accuracy: 0.335000
# lr 2.113268e-07 reg 4.599536e+03 train accuracy: 0.360592 val accuracy: 0.369000
# lr 2.458138e-07 reg 1.918540e+05 train accuracy: 0.284673 val accuracy: 0.296000
# lr 4.297505e-07 reg 1.030681e+05 train accuracy: 0.309265 val accuracy: 0.309000
# lr 4.849789e-07 reg 1.639309e+04 train accuracy: 0.361061 val accuracy: 0.366000
# lr 4.861788e-07 reg 1.546325e+04 train accuracy: 0.360122 val accuracy: 0.369000
# lr 5.284209e-07 reg 2.734971e+05 train accuracy: 0.260327 val accuracy: 0.269000
# lr 5.413144e-07 reg 8.662402e+04 train accuracy: 0.309592 val accuracy: 0.330000
# lr 7.240355e-07 reg 9.435258e+04 train accuracy: 0.296980 val accuracy: 0.303000
# best validation accuracy achieved during cross-validation: 0.372000

# %%
# evaluate on test set
# Evaluate the best softmax on test set
y_test_pred = best_softmax.predict(X_test)
test_accuracy = np.mean(y_test == y_test_pred)
print 'softmax on raw pixels final test set accuracy: %f' % (test_accuracy, )
# Out:
# softmax on raw pixels final test set accuracy: 0.372000

# %%
# Visualize the learned weights for each class
w = best_softmax.W[:-1,:] # strip out the bias
w = w.reshape(32, 32, 3, 10)

w_min, w_max = np.min(w), np.max(w)

classes = ['plane', 'car', 'bird', 'cat', 'deer', 'dog', 'frog', 'horse', 'ship', 'truck']
for i in xrange(10):
  plt.subplot(2, 5, i + 1)
  
  # Rescale the weights to be between 0 and 255
  wimg = 255.0 * (w[:, :, :, i].squeeze() - w_min) / (w_max - w_min)
  plt.imshow(wimg.astype('uint8'))
  plt.axis('off')
  plt.title(classes[i])
